# %%
#Loading required libraries.
import pandas as pd
import numpy as np
import re
import string
from pprint import pprint
from collections import Counter
import keras
import os
import json
import sklearn

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
#Path for the directory.
glove_dir = '/content/drive/My Drive/Colab_Datasets/Hindi_Songs_Lyrics'
embeddings_index = {}

#opening teh file with pretrained words.
f = open(os.path.join(glove_dir, 'lyrics.json'))

lyrics_data_dict = json.load(f)

meta_data = pd.read_csv('/content/drive/My Drive/Colab_Datasets/Hindi_Songs_Lyrics/combined.csv')
lyrics_data_pddf = pd.read_csv('/content/drive/My Drive/Colab_Datasets/Hindi_Songs_Lyrics/lyrics.csv')

# %%
#Function for vectorization of words using bag of words.
def bow_extractor(dataframe, variable_name, ngram_range = (1,3)):
  vectorizer = CountVectorizer(min_df = 1, ngram_range = ngram_range)
  features = vectorizer.fit_transform(dataframe.loc[:, variable_name])
  return vectorizer, features


#Function for creating TFIDF matrix.
def tfidf_transformer(bow_matrix):
  transformer = TfidfTransformer(norm = 'l2', smooth_idf = True, use_idf = True)
  tfidf_matrix = transformer.fit_transform(bow_matrix)
  return transformer, tfidf_matrix


#Function for vectorizing and transforming query into TFIDF smatrix.
def query_vectorization(query, vectorizer, transformer):
  query_features = vectorizer.transform([query])
  query_tfidf = transformer.transform(query_features)
  return query_tfidf, query_features


#Function for creating similarity matrix.
def cos_similarity(search_query_weights, tfidf_weights_matrix):	
  #Calculating cosine distance between documents and query.
	cosine_distance = cosine_similarity(search_query_weights, tfidf_weights_matrix)
	similarity_list = cosine_distance[0]  
	return similarity_list


#Function for suggesting most similar documents.
def most_similar(similarity_list, min_talks = 1):
	most_similar= []
	while min_talks > 0:
		tmp_index = np.argmax(similarity_list)
		most_similar.append(tmp_index)
		similarity_list[tmp_index] = 0
		min_talks -= 1
	return most_similar

# %%
bow_vectorizer, bow_features = bow_extractor(lyrics_data_pddf, 'Lyrics')
transformer, tfidf_matrix = tfidf_transformer(bow_features)

# %%
#query = 'nOdha Jo Tune Mujhko\nSaans Laut Aayi\nChandni Ne Tan Pe Mere\nChaadar Bhichayee\nOdha Jo Tune Mujhko\nSaans Laut Aayi'
query = 'ki inakaa aashiq, mein ban gayaa hoon'
query_tfidf, query_features = query_vectorization(query, bow_vectorizer, transformer)
query_tfidf


similarity_list = cos_similarity(query_tfidf, tfidf_matrix)
sim_songs = most_similar(similarity_list, min_talks = 10)

print(sim_songs)
for i in sim_songs:
  print('\n', "Song: ", meta_data['Song Name'][i])
  print("Lyricist: ", meta_data['Lyricists_1'][i])
  #print("Music Director: ", meta_data['Music_Director_1'])[i]
  print("Singer: ", meta_data['Singer_1'][i])
  print('\n', "Lyrics: ", meta_data['Lyrics'][i])
  print("-----------------------------------------------------------------------------------------", '\n')
# Out:
# [5, 1168, 670, 265, 382, 4, 1114, 1094, 1238, 744]
#
#  Song:  Maula Mere Maula Mere
# Lyricist:  -
# Singer:  Roop Kumar Rathod
#
#  Lyrics:  Maula mere, maula mere
# maula mere, maula mere - 4
# aankhein teri - 2, kitni haseen
# ki inkaa aashiq, mein ban gayaa hoon
# mujhako basaa le, iname tu
# (ishq hai
# maula mere, maula mere maula mere, maula mere - 2) - 3
#
# ki inakaa aashiq, mein ban gayaa hoon
# mujhako basaa le, iname tu
#
# mujhase yeh har ghadi, meraa dil kahe
# tum hi ho usaki aarzoo
# mujhase yeh har ghadi, mere lab kahe
# teri hi ho sab guftagoo
# baatein teri itni haseen, main yaad inko jab kartaa hoon
# phoolon si aaye, khushaboo
#
# rakh loon chhupaa ke main kahin tujhako
# saayaa bhi teraa naa main doon
# rakh loon banaa ke kahin ghar, main tujhe
# saath tere, main hi rahoon
# julfen teri, itni ghani
# dekh ke inako, yeh sochataa hoon
# saaye me, inake main jiyoon
# (ishq hai
# maula mere, maula mere maula mere, maula mere - 2) - 3
#
# (meraa dil yahi bolaa, meraa dil yahi bolaa,
# yaara raaj yeh usane hai mujh par kholaa
# ki hai ishq mohabbat, jiske dil mein
# usko pasand karta hai maulaa) - 3
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Aashiq Mizaaj
# Lyricist:  Siddharth Banerjee
# Singer:  Aman Trikha
#
#  Lyrics:
#
# Shaukeen
# Shaukeen..
#
# They serious, they aint joke
# In moi action-less toe
# In no nonsense no
# Go teen when they saw paradise, shaukeen
# Shaukeen.. paradise
# Shaukeen.. paradise
# Shaukeen.. paradise..
# Cmon now
#
# Fail kiya tha maine university
# Kyun ki bahoot busy tha main karne me aashiqui
# Fail kiya tha maine university
# Kyun ki bahut busy tha main karne me aashiqui
# Mera naada hai dheela, Yeh jaante sabhi
# Phir bhi aaj bhi busy hoon karne me aashiqui
#
# Ab to bandi dekh ki hi samajh jata hun baat ko
# Aayegi ki nahi aayegi woh raat ko - [2]
# Ab to bandi dekh ki hi samajh jata hun baat ko
# Degi ya na degi wo mohabbat aadhi raat ko
#
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo
#
# Compliment kaise dena hai, kaun phasegi kaise
# Kaun na ishq lada paaye hum lade hain jaise
# Kali gori, patli moti ladki sab fantastic
# Shayar casanova,
# Hum hain chaubis ghante full romantic
# Kisi ke naino me jaadu hai, kisi ke gaal gulabi
# Kisi ki chaal me masti hai toh kisi hoth sharabi
# Ab to cutie dekh ke hi daba deta hoon gaal ko
# Machli phans jayegi aise phenkunga me jaal ko
# Ab toh packing dekh ke hi
# Samajh leta hoon maal ko
# Ladki ka main haal bata doon
# Dekh ke uski chaal ko
#
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo
#
# Hey.. dekh liya hai maine poori countri
# Kyunki sikha nahi maine kuch sivaa aashiqui
# Hey.. dekh liya hai maine poori country
# Kyunki sikha nahi maine kuch sivaa aashiqui
#
#
# Maine husn pe ganvaayi saari zindagi
# Kyunki baaki kisi ko samajh na aaye aashiqui
# Ab to titli dekh ke hi samajh jaata hoon baat ko
# Ud jaayegi ya chipak jaayegi meri heart ko
# Ab to khushbu sungh ke hi kar leta hun baat wo
# Sunkar jisko rok na paayegi tu apne aap ko
#
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo..
#
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo
# Aashiq mizaaj, aashiq mizaaj
# Aashiq mizaaj hum yo..
#
#
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Phir Teri
# Lyricist:  Shabbir Ahmed
# Singer:  Sonu Nigam
#
#  Lyrics:
#
# Hey hey hey hey..
# Phir teri woh subah ban jaaun
# Phir teri woh subah ban jaaun
# Oss ban jaaun, woh boond ban jaaun
# Khulegi jab palke teri, woh kiran ban jaaun
# Woh dhoop ban jaaun woh chhanv ban jaaun
# Woh dhoop ban jaaun woh chhanv ban jaaun
# Woh chhanv ban jaaun..
#
# Na na na.. na na na..
#
# Phir teri woh subah ban jaaun
# I'm gonna make you happy
# Never gonna leave you
# Never gonna leave you
# Never gonna leave you
#
# Puja ho ya ibaadat ho
# Puja ho ya ibaadat ho
# Rishte ho ya rasme ho
# Dhundh se dhundhle
# Dhundh se dhundhle tere woh sapne
# Jee karta hai sach kar jaaun
# Sach kar jaaun...
#
# Phir teri woh subah ban jaaun
# Phir teri woh subah ban jaaun
# Oss ban jaaun, woh boond ban jaaun
#
# Main hoon zameen me aasmaan
# Main hoon zameen me aasmaan
# Tu hai shabd mein teri zubaan
# Aadhi adhoori zindagi me
# Main tera lamhaa ban jaaun
#
#
# Phir teri woh subah ban jaaun
# Phir teri woh subah ban jaaun
# Oss ban jaaun, woh boond ban jaaun
# Khulegi jab palke teri, woh kiran ban jaaun
# Woh dhoop ban jaaun woh chhanv ban jaaun
# Woh dhoop ban jaaun woh chhanv ban jaaun
# Woh chhanv ban jaaun..
#
# Na na.. Na na.. Na na na..
# I'm gonna make you happy
# Never gonna leave you
# Never gonna leave you
# Never gonna leave you...
#
#
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Honeymoon Ki Raat
# Lyricist:  Rajat Arora
# Singer:  Sunidhi Chauhan
#
#  Lyrics:
#
# Hmm...
# Honeymoon ki raat hoti hai, main wahi raat hoon
# Uss raat mein jo baat hoti hai, main wahi baat hoon
# Hosh udha de jo dilbar ka, main wahi sharab hoon
# Kaamdev ka sutra padha hai
# Main wahi kitaab hoon, main wahi kitaab hoon
#
# Banjo, si bajti hoon
# Khwaabon, mein sajti hoon
# Karle mere gentlemen, kharaabi zara
# Whisky, si chadhti hoon
# Hichki, si phasti hoon
# Banja mere gentlemen sharaabi zara
# Bhool jaaye hum jo khud ko
# Aisi main tu pila de zara
#
# Kamre mein andhera kar, aankhon ko khol de
# Jo bhi hai tere dil mein, chupke se mehfil mein
# Kaano mein bol de
# Khatre ka darr na kar, har hadh ko todh de
# Zara sa aage badh, tu na mujhse aise lad
# Tu sab mujhpe chod de
#
# Arrey buraa...
# Aa bhoola hai, Rootha hai, chubhta hai, dukhta hai
# Sapna woh jis mein main na hoon
# Main hi main hoon, mehki main hoon
# Mujh mein main tu mila de zara
#
# Har jalwa mera kaatil, main honthon se dasti hoon
# Chhuri si chubti hoon, goli si lagti hoon
# Zehar si chadti hoon
# Har tann pe, sajta hai jo, main aisa sona hoon
# Jalaake jo na jale, bujhake jo na bujhe
# Main aisa shola hoon
#
# Hey jalaa...
# Kala hai, maila hai, ganda hai, bala hai
# Jeena woh jis mein main na hoon
# Main hi main hoon, mehki main hoon
# Mujh mein main tu mila de zara
#
# Honeymoon ki raat hoti hai, main wahi raat hoon
# Haan uss raat mein jo baat hoti hai, main wahi baat hoon
# Hosh udha de jo dilbar ka, main wahi sharaab hoon
# Kaamdev ka sutra padha hai
# Main wahi kitaab hoon, main wahi kitaab hoon
#
# Banjo, si bajti hoon, Khwaabon, mein sajti hoon
# Karle mere gentlemen, kharaabi zara
# Whisky, si chadhti hoon, Hichki, si phasti hoon
# Banja mere gentlemen sharaabi zara
# Bhool jaaye hum jo khud ko
# Aisi main tu pila de zara...
#
#
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Salaam Walekum
# Lyricist:  Adnan Sami
# Singer:  Adnan Sami
#
#  Lyrics:
#
# Dil mera machla jaye qatrah qatrah
# Aise mein kese bolun, aashiq mein tera -[2]
# Chaahne waalon ko tarpana nahi achha
# Is tarah se rooth ke jana nahi acha
#
# Assalaam o walekum jaani dil to deti jaa
# Assalaam o walekum jaani dil to leti jaa
# Assalaam o walekum jaani dil to deti jaa
# Assalaam o walekum jaani dil to leti jaa
#
# Dil mera machla jaye qatrah qatrah
# Aise mein kese bolun, aashiq mein tera -[2]
#
# Jannat ka noor hai ya chandni ka khuwab hai
# Tu har khayal ke sawaal ka jawaab hai
# Wallah kya baat hai rangeen is adaa ki
# Sab se haseen tu saughaat hai khuda ki
# Mein teri tareef ki tareef karta hun
# Dekh ke teri adaaen aah bharta hun
#
#
# Assalaam o walekum jaani dil to deti jaa
# Assalaam o walekum jaani dil to leti jaa
#
# Bandah huzoor ki to aashiqi mein choor hai
# Ye tere rang, tere roop ka qusoor hai
# Chaya jo dharkanon pe wo tera suroor hai
# Meri aawaaz ka anjaam kuch zaroor hai
# Ishq ki deewangi mein doob jaounga
# Rafta rafta mein tere nazdeek aaonga
#
# Assalaam o walekum jaani dil to deti jaa
# Assalaam o walekum jaani dil to leti jaa...
#
#
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Zaraa Maara Maara Sa
# Lyricist:  -
# Singer:  Shaan
#
#  Lyrics:  Zaraa Maara Maara Sa
# Jaane Kyun Dil Ye Ban Ban Ke Banjara
# Darbadar Hai Bhatakta Yun Awaara
# (Zaraa, Zaraa, Zaraa Gumshuda Sa) - 2) - 2
#
# Woo Kya Ptaa Meri Takdeer Kya Hai
# Main Na Jaanu Likha Kya Khuda Ne
# Main Naye Raaste Dhoondta Hoon
# Mil Rahe Hain Puraane Thikaane
# Zaraa Maara Maara Sa
# Jaane Kyun Dil Ye Ban Ban Ke Banjara
# Darbadar Hai Bhatakta Yun Awaara
# (Zaraa, Zaraa, Zaraa Gumshuda Sa) - 2
#
# Hey Main Kahan Aa Gaya Hoon Kahan Se
# Aur Na Jaane Kahan Jaa Rahan Hoon
# Chaan Ke Khaak Rahon Ki Yun Hi
# Yun Hi Jeeta Chale Jaa Raha Hoon
# Zaraa Maara Maara Sa
# Jaane Kyun Dil Ye Ban Ban Ke Banjara
# Darbadar Hai Bhatakta Yun Awaara
# (Zaraa, Zaraa, Zaraa Gumshuda Sa) - 2
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Besharam Title
# Lyricist:  Himanshu Kishan Mehra
# Singer:  Shree D
#
#  Lyrics:
#
# Paida nanga hua toh
# Kaahe ki kaahe ki sharam
# Maai baap naa hi
# Naa koyi dharam
#
# Tedhe medhon se kadak
# Seedhe saadon se naram
# Fun harfun maula hardum
#
# Aaja sab ko dikha de ban
# Dil khole seena taane ban
# Aaja sab ko dikha de ban besharam
# Dil khole seena taane ban besharam
# Aaja thumka laga le ban besharam
# Dil khole seena taane ban besharam
#
# Be is for beimaan
# Sha is for shaitaan
# Rum pee ke jeete hum
# Besharam
#
# Be is for beimaan
# Sha is for shaitaan
# Rum pee ke jeete hum
# Besharam
#
# Haan kare saare hi karam
# Daam puche bina hum
# Waada karke mukarte na hum
# Shuruaat karein hum
# Hum hi karein khatam
# Tod denge tere saare hi bharam
#
# Aaja sab ko dikha de ban besharam
# Dil khole seena taane ban besharam
# Aaja thumka lagaale ban besharam
# Dil khole seena taane ban besharam
#
# Aflatoon aflatoon
# Panga lena in my khoon
# Atrangi atrangi
# Baja dunga sabki pungi
# Chaal mein meri mastiyaan
# Hasti saari hastiyan
# Jab hilaaun apni taang
# Hile saari duniya
#
# Haan dil se bade hi romeo hai
# Harkaton se kare dang
# Pehle toh pyaar se manaaye
# Maane nahi toh hogi jung
#
# Ungli jis pe rakh de hum
# Chalke aaye woh ulte kadam
# Dete kisi ko dard jo hum
# Hum hi lagaate hain marham
#
#
# Chheed lenge..
# O chheed lenge tujhi se tujhi ko aaj hum
# Dil khole seena taane ban besharam
# Aaja thumka lagale ban besharam
# Dil khole seena taane ban besharam
#
# Be is for beimaan
# Sha is for shaitaan
# Rum pee ke jeete hum
# Besharam
#
# Be is for beimaan
# Sha is for shaitaan
# Rum pee ke jeete hum
# Besharam...
#
#
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Tu Khulla Saand Ban Ja
# Lyricist:  Akash Chopra
# Singer:  Salim Sulaiman
#
#  Lyrics:
#
# Ho..
# Jholi sharafat wali khoonti pe taang de
# Chooza banke kar ke miliaa murge ki baang de
# Jholi sharafat wali khoonti pe taang de
# Chooza banke kar ke miliaa murge ki baang de
# Husn ka mela hai, duniya tabela hai
# Control chhad koi kaand kar jaa
#
# Tu khulla saand ban ja haaye..
# Tu khulla saand ban ja
# Tu khulla saand ban ja haaye..
# Tu khulla saand ban ja
#
# Character ki saarangi chhod
# Rangraliyon ka gitar bajaa
# Character ki saarangi chhod
# Rangraliyon ka guitar bajaa
# Rooh ki fixed deposite tod ke
# Jism ka tu udhaar chukaa
# Jumbo jet kudiyaan hain to
# Pilot ka chela hai
# Ayashi ke runway pe land kar ja
#
# Tu khulla saand ban ja haaye..
# Tu khulla saand ban ja
# Tu khulla saand ban ja haaye..
# Tu khulla saand ban ja
#
#
# Ho..
# Mardon ki aankhein hoti hain camera
# Mauka dekh ke zoom badha
# Mardon ki aankhein hoti hain camera
# Mauka dekh ke zoom badhaa
# Apne black and white ushoolon pe
# Naye zamaane ke rang chadha..
# Kaliyon ke garden mein tu
# Bhanwra akela hai
# Baaki tu khud understand kar ja
#
# Tu khulla saand ban ja haaye..
# Tu khulla saand ban ja
# Tu khulla saand ban ja haaye..
# Tu khulla saand ban ja
# Tu khulla saand ban ja haaye..
# Tu khulla saand ban ja...
#
#
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Tere Liye
# Lyricist:  Swanand Kirkire
# Singer:  Sunidhi Chauhan
#
#  Lyrics:
#
# Maine puchha ye dil se
# Main kyu hoon jahan mein
# Ek dhadkan boli tere liye
#
# Mene yaadein taraashi
# Aur khwaab bana di
# Nayee duniya basa di, tere liye..
# Tere liye.. tere liye..
# Tere liye.. tere liye..
#
# Jo main kehta hoon
# Jo sunta hoon
# Jo sehta hoon, tere liye..
# Main girta hoon
# Sambhalta hoon
# Fir chalta hoon, tere liye..
#
# Koyi dard hoon gehra
# Koyi aksh hoon bisra
# Main kya hoon bata de tere liye..
#
# Yaadon ka chahera
# Koi khwaab sunehra
# Main kya hoon bata de tere liye..
#
# Tere liye.. tere liye..
# Tere liye.. tere liye..
#
# Main khoya saa ik lamha hoon
# Bas iss pal hun tere liye
# Main aawara baadal hoon
# Bas iss pal hoon tere liye
# /
#
# Mere har marj ki tu hi davaa hai
# Hui hai jo qubool wo duaa hai
# Yeh ulfat hai ya koi nasha hai
# Jisey chhuna chaahe tu wo dhuaan hai
#
# Tere liye.. tere liye..
# Tere liye.. tere liye..
#
# Jo main kehta hoon
# Jo sunta hoon
# Jo sehta hoon, tere liye..
# Main girta hoon
# Sambhalta hoon
# Phir chalta hoon, tere liye..
# -----------------------------------------------------------------------------------------
#
#
#  Song:  Main Heroine Hoon
# Lyricist:  Amitabh Bhattacharya
# Singer:  Aditi Singh Sharma
#
#  Lyrics:
#
# Poster ke jungle mein
# Glamour ke daldal mein
# Roshni ki hulchul mein
# Gossip mein, scandal mein
# Har dil mein basti hoon
#
# Main heroine hoon.. main heroine hoon
# Main heroine hoon.. main heroine hoon
#
# Jeena marna yeh aaina
# Khud ko bhi toh naa pehchana
# Naqaab banke mera dasna
# Main khiladi hoon ya khilouna
# Kabhi teekhi, kabhi namkeen hoon
#
# Main heroine hoon.. main heroine hoon
# Main heroine hoon.. main heroine hoon
# /
#
# Link-up mein, break-up mein
# Girgit se make-up mein
# Bistar ke silwat mein
# Kahaani ki karwat mein
# Tanha main rehti hoon
#
# Main heroine hoon.. main heroine hoon
# Main heroine hoon.. main heroine hoon...
#
#
# -----------------------------------------------------------------------------------------

# %%
#meta_data
num = 13
print(lyrics_data_pddf['Lyrics'][num])
print(meta_data['Song Name'][num])
# Out:
# Ab duniya se shikwa nahi hai
# Na raha ab zindagi se gila
# Kis ka karam hai, kis ki dua hai
# Ya naseebon se tu mujh ko mila
# Ab jo mile ho, door na jaana
# Tere bina dil lagta nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
#
# I never gonna live without you baby now
# You'll be only one who'll always be my fantasy
# You'll be only one to make me reach my ecstacy
# I don't want nobody else but you
# I'm lovin you, I'm lovin you
#
# Berang se din the, tanha thi raatein
# Kuch na badalta, jo tum na aate
# Berang se din the, tanha thi raatein
# Kuch na badalta, jo tum na aate
# Kehne ko yun toh rishte kayi hain
# Rishton mein koi apna nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
#
# Kyun chuph gaya hai, akhiyon ko meechay
# Sharm-o-haya ke pardon ke peechay
# Kyun chuph gaya hai, akhiyon ko meechay
# Sharm-o-haya ke pardon ke peechay
# Apne sanam se parda hai kaisa
# Jab ke khuda se parda nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
#
#
# Ab duniya se shikwa nahi hai
# Na raha ab zindagi se gila
# Kis ka karam hai, kis ki dua hai
# Ya naseebon se tu mujh ko mila
# Ab jo mile ho, door na jaana
# Tere bina dil lagta nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
# Mera jeena hai kya, marna hai kya, jab saath tera nahi
# Paake rab kya karun, jab tu hi mera nahi
# Mera Jeena Hai Kya

# %%
#Function for creating weight matrix.
def tf_idf(search_keys, dataframe, label):
  
	tfidf_vectorizer = TfidfVectorizer()
	tfidf_weights_matrix = tfidf_vectorizer.fit_transform(dataframe.loc[:, label])
	search_query_weights = tfidf_vectorizer.transform([search_keys])	
	return search_query_weights, tfidf_weights_matrix

#Function for creating similarity matrix.
def cos_similarity(search_query_weights, tfidf_weights_matrix):
	
	cosine_distance = cosine_similarity(search_query_weights, tfidf_weights_matrix)
	similarity_list = cosine_distance[0]  
	return similarity_list

#Function for suggesting most similar documents.
def most_similar(similarity_list, min_talks = 1):
	
	most_similar= []
	while min_talks > 0:
		tmp_index = np.argmax(similarity_list)
		most_similar.append(tmp_index)
		similarity_list[tmp_index] = 0
		min_talks -= 1
	return most_similar



#Testing the functions!!!
search_keys = 'ki inakaa aashiq, mein ban gayaa hoon mujhako basaa le, iname tu mujhase yeh har ghadi, meraa dil kahe tum hi ho usaki aarzoo mujhase yeh har ghadi, mere lab kahe teri hi ho sab guftagoo baatein teri itni haseen, main yaad inko jab kartaa hoon phoolon si aaye, khushaboo'
dataframe = lyrics_data_pddf
label = 'Lyrics'

search_query_weights, tfidf_weights_matrix = tf_idf(search_keys, dataframe, label)
similarity_list = cos_similarity(search_query_weights, tfidf_weights_matrix)
most_similar(similarity_list, min_talks = 10)
